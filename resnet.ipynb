# %%
import torch            		# 导入 torch
import torch.nn as nn     		#  torch的网络组建
import torch.nn.functional as F	#  搭建网络
import torch.optim as optim		# 优化器
import torchvision				# 数据相关
from torchvision import transforms  # 数据处理与增强
import time
import copy
import warnings 
import matplotlib.pyplot as plt 
import numpy as np
from skimage import io
import skimage.transform as tr
plt.style.use('seaborn')
warnings.filterwarnings('ignore')
# Out:
# C:\Users\ZKM\AppData\Local\Temp\ipykernel_14816\1585452625.py:14: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
train_dir = '../data/train/'
test_dir = '../data/test/'

# %%
train_transform = transforms.Compose([
    transforms.Resize((256,256)),       #  输入尺寸
    transforms.RandomCrop((224,224)),  #  裁剪尺寸
    transforms.RandomHorizontalFlip(p=0.5),  # 随机水平翻转
    transforms.ColorJitter(
        brightness=(0.7,1.3),  # 明暗程度
        contrast=(0.7,1.3),    # 对比度
        saturation=(0.7,1.3),  # 饱和度
        hue=(-0.05,0.05)),     # 颜色
    transforms.ToTensor(),    # 数据转为张量并做归一化
    transforms.Normalize(   # 数据标准化
        mean = [.5,.5,.5],    # RGB均值
        std = [.5,.5,.5])      # RGB 方差  （可以使用经验值（查阅））
])
test_transform = transforms.Compose([
    transforms.Resize((224,224)),   # 输入尺寸（在预测中应遵循此尺寸）
    transforms.ToTensor(),         # 张量      
    transforms.Normalize(         # 标准化
        mean = [.5,.5,.5],
        std = [.5,.5,.5])
])

# %%
train_ds = torchvision.datasets.ImageFolder(
    train_dir,    # 导入训练文件夹路径
    transform=train_transform  # 数据处理与增强
)
test_ds = torchvision.datasets.ImageFolder(
    test_dir,     # 导入测试文件夹路径
    transform=test_transform   # 数据处理与增强

)
# 创建dl
BATCHSIZE = 8  # batch_size的批量尺寸
train_dl = torch.utils.data.DataLoader(
    train_ds,   # 将打包好的数据生成可迭代的batch_size个数的批量数据
    batch_size=BATCHSIZE,  # batch_size 值得选择应对照本机配置
    shuffle=True   # 打乱（必须打乱否则模型会识别顺序）
)
test_dl = torch.utils.data.DataLoader(
    test_ds,      
    batch_size=BATCHSIZE
)

# %%
model = torchvision.models.resnet18(pretrained=True)
model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %%
# model.features.pool0.kernel_size=2
#model.fc.out_features = 9 #设置cat dog的分类
# 冻结 卷积基 操作
for param in model.parameters():
    param.requires_grad = False
model.fc=nn.Linear(model.fc.in_features,9)
# model.add_module('fc_relu',nn.ReLU(inplace=True))
# model.add_module('fc_dp',nn.Dropout(p=0.5, inplace=False))
# model.add_module('fc1',nn.Linear(256,256))
# model.add_module('fc1_relu',nn.ReLU(inplace=True))
# model.add_module('fc1_dp',nn.Dropout(p=0.5, inplace=False))
# model.add_module('fc2',nn.Linear(256,9))
# model.add_module('fc1_relu',nn.ReLU(inplace=True))
# # model.add_module('fc1_dp',nn.Dropout(p=0.5, inplace=False))

# model.fc=nn.Linear(model.fc.in_features,9)
model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=9, bias=True)
# )

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(),lr=0.0001)
exp_lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,step_size=20,gamma=0.1)
device =torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

# %%
# 搭建训练步骤
def train(dataloader,model,loss_fn,optimizer):
    # acc 当前样本一共有多少个
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    # 初始化loss值
    train_loss,correct = 0,0
    model.train()  # 模式为训练模式
    for X,y in dataloader:
        # 前向传播（推理）
        X,y = X.to(device),y.to(device)
        pred = model(X)
        # 产生误差
        loss = loss_fn(pred,y)  # 返回平均误差
        # loss = torch.nn.functional.cross_entropy(pred, y)
        # 归零权重(固定写法)
        optimizer.zero_grad()
        # 反向传递
        loss.backward()
        # 利用梯度下降优化参数
        optimizer.step()
        # # 放弃张量微分的追踪（小验证）
        with torch.no_grad():
            train_loss += loss.item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    exp_lr_scheduler.step()
    lr_res = optimizer.state_dict()['param_groups'][0]['lr']
    correct /= size        
    train_loss /= num_batches
    return train_loss,correct,lr_res

# %%
# 搭建测试 （test）
def test(dataloader,model):
    # acc 当前样本一共有多少个
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss,correct = 0,0
    model.eval()  # 推理模式
    with torch.no_grad():
        for X,y in dataloader:
            X,y = X.to(device),y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred,y)
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    correct /= size        
    test_loss /= num_batches
    return test_loss,correct

# %%
best_model_wts = copy.deepcopy(model.state_dict()) # 用以记录模型最优参数
best_acc = 0.0
epochs = 50
train_acc = []
train_loss = []
test_acc = []
test_loss = []
for epoch in range(epochs):
    start  =  time.time()
    epoch_loss,epoch_acc,lr = train(dataloader=train_dl,model=model,loss_fn=loss_fn,optimizer=optimizer)
    epoch_test_loss,epoch_test_acc = test(dataloader=test_dl,model=model)
    end = time.time()
    times = end - start 
    train_acc.append(epoch_acc)
    train_loss.append(epoch_loss)
    test_acc.append(epoch_test_acc)
    test_loss.append(epoch_test_loss)
    print('训练epoch{},训练集损失值:{:.2f},训练集的准确率:{:.2f}%,测试集损失值:{:.2f},测试集的准确率:{:.2f}%,当前学习率:{},消耗时间：{:.2f}s'.
          format(epoch+1,epoch_loss,epoch_acc*100,epoch_test_loss,epoch_test_acc*100,lr,times))
    # 保存best——model
    if epoch_test_acc > best_acc:  # 如果当前的test_acc 高于best_acc 执行保存
        best_acc = epoch_test_acc
        best_model_wts = copy.deepcopy(model.state_dict())
print('训练结束并保存最好权重模型')
# Out:
# 训练epoch1,训练集损失值:1.46,训练集的准确率:53.62%,测试集损失值:0.64,测试集的准确率:82.43%,当前学习率:0.0001,消耗时间：720.92s
# 训练epoch2,训练集损失值:0.99,训练集的准确率:70.10%,测试集损失值:0.51,测试集的准确率:84.16%,当前学习率:0.0001,消耗时间：251.10s
# 训练epoch3,训练集损失值:0.86,训练集的准确率:72.96%,测试集损失值:0.41,测试集的准确率:87.38%,当前学习率:0.0001,消耗时间：256.49s
# 训练epoch4,训练集损失值:0.79,训练集的准确率:74.82%,测试集损失值:0.37,测试集的准确率:88.29%,当前学习率:0.0001,消耗时间：252.46s
# 训练epoch5,训练集损失值:0.75,训练集的准确率:75.68%,测试集损失值:0.36,测试集的准确率:88.76%,当前学习率:0.0001,消耗时间：319.13s
# 训练epoch6,训练集损失值:0.73,训练集的准确率:76.39%,测试集损失值:0.35,测试集的准确率:88.63%,当前学习率:0.0001,消耗时间：299.66s
# 训练epoch7,训练集损失值:0.70,训练集的准确率:77.22%,测试集损失值:0.35,测试集的准确率:88.94%,当前学习率:0.0001,消耗时间：258.98s
# 训练epoch8,训练集损失值:0.69,训练集的准确率:76.95%,测试集损失值:0.31,测试集的准确率:90.02%,当前学习率:0.0001,消耗时间：256.97s
# 训练epoch9,训练集损失值:0.67,训练集的准确率:77.76%,测试集损失值:0.36,测试集的准确率:87.51%,当前学习率:0.0001,消耗时间：255.94s
# 训练epoch10,训练集损失值:0.66,训练集的准确率:77.72%,测试集损失值:0.32,测试集的准确率:89.98%,当前学习率:0.0001,消耗时间：257.37s
# 训练epoch11,训练集损失值:0.65,训练集的准确率:78.18%,测试集损失值:0.33,测试集的准确率:88.81%,当前学习率:0.0001,消耗时间：260.18s
# 训练epoch12,训练集损失值:0.64,训练集的准确率:78.44%,测试集损失值:0.32,测试集的准确率:89.02%,当前学习率:0.0001,消耗时间：262.78s
# 训练epoch13,训练集损失值:0.63,训练集的准确率:78.99%,测试集损失值:0.28,测试集的准确率:91.15%,当前学习率:0.0001,消耗时间：263.23s
# 训练epoch14,训练集损失值:0.64,训练集的准确率:78.74%,测试集损失值:0.30,测试集的准确率:90.41%,当前学习率:0.0001,消耗时间：265.05s
# 训练epoch15,训练集损失值:0.62,训练集的准确率:79.06%,测试集损失值:0.31,测试集的准确率:89.98%,当前学习率:0.0001,消耗时间：258.34s
# 训练epoch16,训练集损失值:0.62,训练集的准确率:79.25%,测试集损失值:0.28,测试集的准确率:91.02%,当前学习率:0.0001,消耗时间：264.31s
# 训练epoch17,训练集损失值:0.62,训练集的准确率:79.13%,测试集损失值:0.29,测试集的准确率:90.59%,当前学习率:0.0001,消耗时间：260.03s
# 训练epoch18,训练集损失值:0.60,训练集的准确率:79.58%,测试集损失值:0.27,测试集的准确率:91.67%,当前学习率:0.0001,消耗时间：264.64s
# 训练epoch19,训练集损失值:0.61,训练集的准确率:79.70%,测试集损失值:0.28,测试集的准确率:90.80%,当前学习率:0.0001,消耗时间：259.62s
# 训练epoch20,训练集损失值:0.61,训练集的准确率:79.27%,测试集损失值:0.28,测试集的准确率:91.06%,当前学习率:1e-05,消耗时间：260.16s
# 训练epoch21,训练集损失值:0.59,训练集的准确率:79.85%,测试集损失值:0.29,测试集的准确率:90.41%,当前学习率:1e-05,消耗时间：260.13s
# 训练epoch22,训练集损失值:0.59,训练集的准确率:80.35%,测试集损失值:0.28,测试集的准确率:90.85%,当前学习率:1e-05,消耗时间：264.02s
# 训练epoch23,训练集损失值:0.59,训练集的准确率:80.24%,测试集损失值:0.28,测试集的准确率:90.85%,当前学习率:1e-05,消耗时间：261.22s
# 训练epoch24,训练集损失值:0.59,训练集的准确率:80.17%,测试集损失值:0.30,测试集的准确率:90.02%,当前学习率:1e-05,消耗时间：256.19s
# 训练epoch25,训练集损失值:0.59,训练集的准确率:80.24%,测试集损失值:0.27,测试集的准确率:90.89%,当前学习率:1e-05,消耗时间：260.77s
# 训练epoch26,训练集损失值:0.59,训练集的准确率:79.86%,测试集损失值:0.29,测试集的准确率:90.76%,当前学习率:1e-05,消耗时间：263.94s
# 训练epoch27,训练集损失值:0.59,训练集的准确率:80.17%,测试集损失值:0.26,测试集的准确率:91.50%,当前学习率:1e-05,消耗时间：258.15s
# 训练epoch28,训练集损失值:0.60,训练集的准确率:79.58%,测试集损失值:0.29,测试集的准确率:90.33%,当前学习率:1e-05,消耗时间：256.14s
# 训练epoch29,训练集损失值:0.60,训练集的准确率:80.02%,测试集损失值:0.26,测试集的准确率:91.63%,当前学习率:1e-05,消耗时间：262.59s
# 训练epoch30,训练集损失值:0.60,训练集的准确率:79.97%,测试集损失值:0.26,测试集的准确率:91.89%,当前学习率:1e-05,消耗时间：259.41s
# 训练epoch31,训练集损失值:0.60,训练集的准确率:79.74%,测试集损失值:0.26,测试集的准确率:91.45%,当前学习率:1e-05,消耗时间：261.74s
# 训练epoch32,训练集损失值:0.60,训练集的准确率:80.33%,测试集损失值:0.27,测试集的准确率:91.11%,当前学习率:1e-05,消耗时间：261.26s
# 训练epoch33,训练集损失值:0.59,训练集的准确率:80.07%,测试集损失值:0.29,测试集的准确率:90.93%,当前学习率:1e-05,消耗时间：258.68s
# 训练epoch34,训练集损失值:0.59,训练集的准确率:80.07%,测试集损失值:0.29,测试集的准确率:90.20%,当前学习率:1e-05,消耗时间：257.50s
# 训练epoch35,训练集损失值:0.59,训练集的准确率:79.97%,测试集损失值:0.26,测试集的准确率:91.84%,当前学习率:1e-05,消耗时间：262.84s
# 训练epoch36,训练集损失值:0.60,训练集的准确率:79.58%,测试集损失值:0.28,测试集的准确率:90.98%,当前学习率:1e-05,消耗时间：260.80s
# 训练epoch37,训练集损失值:0.58,训练集的准确率:80.55%,测试集损失值:0.27,测试集的准确率:91.24%,当前学习率:1e-05,消耗时间：262.27s
# 训练epoch38,训练集损失值:0.59,训练集的准确率:80.07%,测试集损失值:0.29,测试集的准确率:90.76%,当前学习率:1e-05,消耗时间：263.57s
# 训练epoch39,训练集损失值:0.59,训练集的准确率:80.23%,测试集损失值:0.29,测试集的准确率:90.28%,当前学习率:1e-05,消耗时间：261.31s
# 训练epoch40,训练集损失值:0.58,训练集的准确率:80.25%,测试集损失值:0.27,测试集的准确率:91.32%,当前学习率:1.0000000000000002e-06,消耗时间：260.17s
# 训练epoch41,训练集损失值:0.59,训练集的准确率:80.18%,测试集损失值:0.27,测试集的准确率:91.58%,当前学习率:1.0000000000000002e-06,消耗时间：262.33s
# 训练epoch42,训练集损失值:0.59,训练集的准确率:80.32%,测试集损失值:0.27,测试集的准确率:91.24%,当前学习率:1.0000000000000002e-06,消耗时间：259.86s
# 训练epoch43,训练集损失值:0.59,训练集的准确率:80.03%,测试集损失值:0.27,测试集的准确率:91.58%,当前学习率:1.0000000000000002e-06,消耗时间：288.31s
# 训练epoch44,训练集损失值:0.59,训练集的准确率:80.04%,测试集损失值:0.29,测试集的准确率:90.59%,当前学习率:1.0000000000000002e-06,消耗时间：513.19s
# 训练epoch45,训练集损失值:0.58,训练集的准确率:80.47%,测试集损失值:0.27,测试集的准确率:91.37%,当前学习率:1.0000000000000002e-06,消耗时间：505.79s
# 训练epoch46,训练集损失值:0.58,训练集的准确率:80.45%,测试集损失值:0.28,测试集的准确率:91.32%,当前学习率:1.0000000000000002e-06,消耗时间：586.24s
# 训练epoch47,训练集损失值:0.59,训练集的准确率:80.18%,测试集损失值:0.29,测试集的准确率:90.54%,当前学习率:1.0000000000000002e-06,消耗时间：585.79s
# 训练epoch48,训练集损失值:0.59,训练集的准确率:80.35%,测试集损失值:0.28,测试集的准确率:90.89%,当前学习率:1.0000000000000002e-06,消耗时间：516.99s
# 训练epoch49,训练集损失值:0.58,训练集的准确率:80.39%,测试集损失值:0.28,测试集的准确率:91.28%,当前学习率:1.0000000000000002e-06,消耗时间：587.19s
# 训练epoch50,训练集损失值:0.59,训练集的准确率:80.25%,测试集损失值:0.29,测试集的准确率:91.02%,当前学习率:1.0000000000000002e-06,消耗时间：584.71s
# 训练结束并保存最好权重模型

# %%
## 训练曲线可视化
# 损失值
train_loss_min_index = np.argmin(np.array(train_loss))
train_loss_min_value = round(train_loss[train_loss_min_index],6)
test_loss = torch.stack(test_loss).cpu().numpy()
test_loss_min_index = np.argmin(np.array(test_loss))
test_loss_min_value = round(test_loss[test_loss_min_index].item(),6)

s = train_loss_min_value
s_test = test_loss_min_value
plt.plot(range(1,epoch+2),train_loss,label='train_loss')
plt.plot(range(1,epoch+2),test_loss,label='test_loss')
plt.text(train_loss_min_index, train_loss_min_value+0.1, s)
plt.text(test_loss_min_index, test_loss_min_value+0.1, s_test)
plt.plot(train_loss_min_index+1,train_loss_min_value,'ro')
plt.plot(test_loss_min_index+1,test_loss_min_value,'bo')
plt.title('ResNet_Loss values')
plt.legend()

plt.savefig('../pic/ResNet_Loss')

# %%
## 训练曲线可视化
# 准确率
train_acc_max_index = np.argmax(np.array(train_acc))
train_acc_max_value = round(train_acc[train_acc_max_index],6)
test_acc_max_index = np.argmax(np.array(test_acc))
test_acc_max_value = round(test_acc[test_acc_max_index],6)

s = train_acc_max_value
s_test = test_acc_max_value
plt.plot(range(1,epoch+2),train_acc,label='train_acc')
plt.plot(range(1,epoch+2),test_acc,label='test_acc')
plt.text(train_acc_max_index, train_acc_max_value-0.02, s)
plt.text(test_acc_max_index, test_acc_max_value+0.01, s_test)
plt.plot(train_acc_max_index+1,train_acc_max_value,'bo')
plt.plot(test_acc_max_index+1,test_acc_max_value,'go')
plt.title('ResNet_Acc values')
plt.ylim(0.5,1.08)
plt.xlim(0,51)
plt.legend()

plt.savefig('../pic/ResNet_Acc')

# %%
torch.save(model.state_dict(),'../model/ResNet.pth')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 torch.save(model.state_dict(),'../model/ResNet.pth')
#
# NameError: name 'torch' is not defined
